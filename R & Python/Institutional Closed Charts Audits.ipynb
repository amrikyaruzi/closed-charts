# %%
# %load "C:/Users/amri.kyaruzi/Documents/Programming/Python/Codes/Closed Charts codes/Departmental codes/Closed Charts - Institutional.ipy"
"""
Created on Wed Apr 15 09:46:54 2020

@author: amri.kyaruzi
"""
# %reset -f

#Institutional data:
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

data = pd.read_csv(r"C:\Users\amri.kyaruzi\Documents\SEPTEMBER OME DETAILS.csv", engine='python')
print(data.head())

# Institutional Filters
is_DAE = (data['DEPT'] == 'DAE')
is_DOA = (data['DEPT'] == 'DOA') & ((data['SNN'] == 1.3) | (data['SNN'] == 4.1) | (data['SNN'] == 5.1) | (data['SNN'] == 5.2) | (data['SNN'] == 5.3) | (data['SNN'] == 5.5) | (data['SNN'] == 7.2))
is_DOG = (data['DEPT'] == 'DOG') & ((data['SNN'] == 1.1) | (data['SNN'] == 1.2) | (data['SNN'] == 1.4) | (data['SNN'] == 2.1) | (data['SNN'] == 2.2) | (data['SNN'] == 2.3) | (data['SNN'] == 3.1) | (data['SNN'] == 3.2) | (data['SNN'] == 3.3) | (data['SNN'] == 4.1) | (data['SNN'] == 5.2) | (data['SNN'] == 5.4) | (data['SNN'] == 5.5) | (data['SNN'] == 6.1) | (data['SNN'] == 7.1) | (data['SNN'] == 7.3) | (data['SNN'] == 8.1))
is_DOM = (data['DEPT'] == 'DOM') & ((data['SNN'] == 1.1) | (data['SNN'] == 1.2) | (data['SNN'] == 1.3) | (data['SNN'] == 1.4) | (data['SNN'] == 2.1) | (data['SNN'] == 2.2) | (data['SNN'] == 2.3) | (data['SNN'] == 3.1) | (data['SNN'] == 3.2) | (data['SNN'] == 3.3) | (data['SNN'] == 4.1) | (data['SNN'] == 5.2) | (data['SNN'] == 5.4) | (data['SNN'] == 5.5) | (data['SNN'] == 6.1) | (data['SNN'] == 7.1) | (data['SNN'] == 7.3) | (data['SNN'] == 8.1))
is_DOP = (data['DEPT'] == 'DOP') & ((data['SNN'] == 1.1) | (data['SNN'] == 1.2) | (data['SNN'] == 1.4) | (data['SNN'] == 2.1) | (data['SNN'] == 2.2) | (data['SNN'] == 2.3) | (data['SNN'] == 3.1) | (data['SNN'] == 3.2) | (data['SNN'] == 3.3) | (data['SNN'] == 4.1) | (data['SNN'] == 5.2) | (data['SNN'] == 5.4) | (data['SNN'] == 5.5) | (data['SNN'] == 6.1) | (data['SNN'] == 8.1))
is_DON = (data['DEPT'] == 'DON') & ((data['SNN'] == 1.5) | (data['SNN'] == 2.1) | (data['SNN'] == 3.1) | (data['SNN'] == 3.2))
is_DOS = (data['DEPT'] == 'DOS') & ((data['SNN'] == 1.1) | (data['SNN'] == 1.2) | (data['SNN'] == 1.4) | (data['SNN'] == 2.1) | (data['SNN'] == 2.2) | (data['SNN'] == 2.3) | (data['SNN'] == 3.1) | (data['SNN'] == 3.2) | (data['SNN'] == 3.3) | (data['SNN'] == 4.1) | (data['SNN'] == 5.2) | (data['SNN'] == 5.4) | (data['SNN'] == 5.5) | (data['SNN'] == 6.1) | (data['SNN'] == 7.1) | (data['SNN'] == 7.3) | (data['SNN'] == 8.1))
is_RM = (data['DEPT'] == 'RM') & ((data['SNN'] == 1.4) | (data['SNN'] == 1.6) | (data['SNN'] == 1.7) | (data['SNN'] == 2.1) | (data['SNN'] == 3.1))

# Institutional dataset
mydata = data[is_DOA | is_DOG | is_DOM | is_DOP | is_DON | is_DOS | is_RM | is_DAE]

# Filters
is_documented = (mydata['DOCUMENTED'] == 'D') | (mydata['DOCUMENTED'] == 'ND')
is_timely = (mydata['TIMELY'] == 'Y') | (mydata['TIMELY'] == 'N')
is_legible = (mydata['LEGIBLE'] == 'Y') | (mydata['LEGIBLE'] == 'N')
is_complete = (mydata['COMPLETE'] == 'Y') | (mydata['COMPLETE'] == 'N')
is_met = (mydata['MET'] == 'M') | (mydata['MET'] == 'NM')

# Filtered Dataframes
documentedInstitutional = mydata[is_documented]
timelyInstitutional = mydata[is_timely]
legibleInstitutional = mydata[is_legible]
completeInstitutional = mydata[is_complete]
metInstitutional = mydata[is_met]

is_doctor = mydata['TYPE'] == 'P'
is_nurse = mydata['TYPE'] == 'N'

#Results_stored in dataframe
# Closed Charts Data - Institutional:
print('DOCUMENTED SCORES INSTITUTIONAL')
print(documentedInstitutional['DOCUMENTED'].value_counts(normalize=True).mul(100).round(2).astype(str) + '%')
print('')
print('TIMELINESS SCORES INSTITUTIONAL')
print(timelyInstitutional['TIMELY'].value_counts(normalize=True).mul(100).round(2).astype(str) + '%')
print('')
print('LEGIBILITY SCORES INSTITUTIONAL')
print(legibleInstitutional['LEGIBLE'].value_counts(normalize=True).mul(100).round(2).astype(str) + '%')
print('')
print('COMPLETENESS SCORES INSTITUTIONAL')
print(completeInstitutional['COMPLETE'].value_counts(normalize=True).mul(100).round(2).astype(str) + '%')
print('')
print('OVERALL COMPLIANCE SCORES INSTITUTIONAL')
print(metInstitutional['MET'].value_counts(normalize=True).mul(100).round(2).astype(str) + '%')
print('')

# Scores vs Documents
documented = documentedInstitutional.groupby('DOCUMENTS')['DOCUMENTED'].value_counts(normalize=True).mul(100).round(2).sort_values(ascending = False).astype('str') + "%"
Documented_Scores = documented.to_frame()

timely = timelyInstitutional.groupby('DOCUMENTS')['TIMELY'].value_counts(normalize=True).mul(100).round(2).sort_values(ascending = False).astype('str') + "%"
Timeliness_Scores = timely.to_frame()

legible = legibleInstitutional.groupby('DOCUMENTS')['LEGIBLE'].value_counts(normalize=True).mul(100).round(2).sort_values(ascending = False).astype('str') + "%"
Legibility_Scores = legible.to_frame()

complete = completeInstitutional.groupby('DOCUMENTS')['COMPLETE'].value_counts(normalize=True).mul(100).round(2).sort_values(ascending = False).astype('str') + "%"
Completeness_Scores = complete.to_frame()

met = metInstitutional.groupby('DOCUMENTS')['MET'].value_counts(normalize=True).mul(100).round(2).sort_values(ascending = False).astype('str') + "%"
Met_Scores = met.to_frame()

print('Summary per Parameter')

print(Documented_Scores)
print('')

print(Timeliness_Scores)
print('')

print(Legibility_Scores)
print('')

print(Completeness_Scores)
print('')

print(Met_Scores)
print("END OF OVERALL INSTITUTIONAL SCORES")
print("*********************************************************")
print("")

#Physician only overall scores
documentedPHYSICIAN = mydata[is_doctor & is_documented]
timelyPHYSICIAN = mydata[is_doctor & is_timely]
legiblePHYSICIAN = mydata[is_doctor & is_legible]
completePHYSICIAN = mydata[is_doctor & is_complete]
metPHYSICIAN = mydata[is_doctor & is_met]

print("PHYSICIAN ONLY SCORES - DOCUMENTED")
print(documentedPHYSICIAN['DOCUMENTED'].value_counts(normalize=True).mul(100).round(1).astype('str') + "%")
print("")
print("PHYSICIAN ONLY SCORES - TIMELY")
print(timelyPHYSICIAN['TIMELY'].value_counts(normalize=True).mul(100).round(1).astype('str') + "%")
print("")
print("PHYSICIAN ONLY SCORES - LEGIBILITY")
print(legiblePHYSICIAN['LEGIBLE'].value_counts(normalize=True).mul(100).round(1).astype('str') + "%")
print("")
print("PHYSICIAN ONLY SCORES - COMPLETENESS")
print(completePHYSICIAN['COMPLETE'].value_counts(normalize=True).mul(100).round(1).astype('str') + "%")
print("")
print("PHYSICIAN ONLY SCORES - OVERALL SCORES")
print(metPHYSICIAN['MET'].value_counts(normalize=True).mul(100).round(1).astype('str') + "%")
print("")

print(documentedPHYSICIAN.groupby('DOCUMENTS')['DOCUMENTED'].value_counts(normalize=True).mul(100).round(1).sort_values(ascending = False).astype('str') + "%")
print("")
print(timelyPHYSICIAN.groupby('DOCUMENTS')['TIMELY'].value_counts(normalize=True).mul(100).round(1).sort_values(ascending = False).astype('str') + "%")
print("")
print(legiblePHYSICIAN.groupby('DOCUMENTS')['LEGIBLE'].value_counts(normalize=True).mul(100).round(1).sort_values(ascending = False).astype('str') + "%")
print("")
print(completePHYSICIAN.groupby('DOCUMENTS')['COMPLETE'].value_counts(normalize=True).mul(100).round(1).sort_values(ascending = False).astype('str') + "%")
print("")
print(metPHYSICIAN.groupby('DOCUMENTS')['MET'].value_counts(normalize=True).mul(100).round(1).sort_values(ascending = False).astype('str') + "%")
print("END OF PHYSICIAN SCORES")
print("*********************************************************")
print("")

#Nurses only overall scores
documentedNURSES = mydata[is_nurse & is_documented]
timelyNURSES = mydata[is_nurse & is_timely]
legibleNURSES = mydata[is_nurse & is_legible]
completeNURSES = mydata[is_nurse & is_complete]
metNURSES = mydata[is_nurse & is_met]

print("NURSES ONLY SCORES - DOCUMENTED")
print(documentedNURSES['DOCUMENTED'].value_counts(normalize=True).mul(100).round(1).astype('str') + "%")
print("")
print("NURSES ONLY SCORES - TIMELY")
print(timelyNURSES['TIMELY'].value_counts(normalize=True).mul(100).round(1).astype('str') + "%")
print("")
print("NURSES ONLY SCORES - LEGIBILITY")
print(legibleNURSES['LEGIBLE'].value_counts(normalize=True).mul(100).round(1).astype('str') + "%")
print("")
print("NURSES ONLY SCORES - COMPLETENESS")
print(completeNURSES['COMPLETE'].value_counts(normalize=True).mul(100).round(1).astype('str') + "%")
print("")
print("NURSES ONLY SCORES - OVERALL SCORES")
print(metNURSES['MET'].value_counts(normalize=True).mul(100).round(1).astype('str') + "%")
print("")

print(documentedNURSES.groupby('DOCUMENTS')['DOCUMENTED'].value_counts(normalize=True).mul(100).round(1).sort_values(ascending = False).astype('str') + "%")
print("")
print(timelyNURSES.groupby('DOCUMENTS')['TIMELY'].value_counts(normalize=True).mul(100).round(1).sort_values(ascending = False).astype('str') + "%")
print("")
print(legibleNURSES.groupby('DOCUMENTS')['LEGIBLE'].value_counts(normalize=True).mul(100).round(1).sort_values(ascending = False).astype('str') + "%")
print("")
print(completeNURSES.groupby('DOCUMENTS')['COMPLETE'].value_counts(normalize=True).mul(100).round(1).sort_values(ascending = False).astype('str') + "%")
print("")
print(metNURSES.groupby('DOCUMENTS')['MET'].value_counts(normalize=True).mul(100).round(1).sort_values(ascending = False).astype('str') + "%")
print("END OF NURSING SCORES")
print("*********************************************************")
print("")
# Out:
#    Unnamed: 0       AKNO             PATIENT.NAMES  ADMNO           ADMDATE  \
# 0           1  052-68-84  REHEMA FRANCIS MUTONGOLE  72397  04/09/2020 00:00
# 1           2  052-68-84  REHEMA FRANCIS MUTONGOLE  72397  04/09/2020 00:00
# 2           3  052-68-84  REHEMA FRANCIS MUTONGOLE  72397  04/09/2020 00:00
# 3           4  052-68-84  REHEMA FRANCIS MUTONGOLE  72397  04/09/2020 00:00
# 4           5  052-68-84  REHEMA FRANCIS MUTONGOLE  72397  04/09/2020 00:00
#
#           DISCHDATE   DOC_CODE           DOCTOR DEPT  SN             SECTION  \
# 0  06/09/2020 00:00  DOG 00034  Jaiswal, Shweta  DOG   1  Initial Assessment
# 1  06/09/2020 00:00  DOG 00034  Jaiswal, Shweta  DOG   1  Initial Assessment
# 2  06/09/2020 00:00  DOG 00034  Jaiswal, Shweta  DOG   1  Initial Assessment
# 3  06/09/2020 00:00  DOG 00034  Jaiswal, Shweta  DOG   1  Initial Assessment
# 4  06/09/2020 00:00  DOG 00034  Jaiswal, Shweta  DOG   1  Initial Assessment
#
#    SNN                                          DOCUMENTS TYPE DOCUMENTED  \
# 0  1.1        Physician Initial Assessment All components    P          D
# 1  1.2          Nursing Initial Assessment All components    N          D
# 2  1.3       Pre-Operative Anesthesia/Sedation Assessment    P        NaN
# 3  1.4  Appropriate pain assessment, intervention and ...    N          D
# 4  1.5              Nutritional Assessment All components    P        NaN
#
#   TIMELY LEGIBLE COMPLETE  MET
# 0      Y       Y        Y    M
# 1      Y       N        Y   NM
# 2      -       -        -  NaN
# 3      Y       Y        N   NM
# 4      -       -        -  NaN
# DOCUMENTED SCORES INSTITUTIONAL
# D     97.97%
# ND     2.03%
# Name: DOCUMENTED, dtype: object
#
# TIMELINESS SCORES INSTITUTIONAL
# Y    97.51%
# N     2.49%
# Name: TIMELY, dtype: object
#
# LEGIBILITY SCORES INSTITUTIONAL
# Y    80.26%
# N    19.74%
# Name: LEGIBLE, dtype: object
#
# COMPLETENESS SCORES INSTITUTIONAL
# Y    85.5%
# N    14.5%
# Name: COMPLETE, dtype: object
#
# OVERALL COMPLIANCE SCORES INSTITUTIONAL
# M     65.42%
# NM    34.58%
# Name: MET, dtype: object
#
# Summary per Parameter
#                                                               DOCUMENTED
# DOCUMENTS                                          DOCUMENTED
# Surgical Procedure/ Operative notes                D              100.0%
# Check Consent forms for any abbreviations          D              100.0%
# Intraoperative Notes of Anesthesia                 D              100.0%
# Discharge/Transfer/Referral Summary at exit        D              100.0%
# Intraoperative form for Site marking, sign in, ... D              100.0%
# Check the Discharge summary and DNR forms for a... D              100.0%
# Pre-Operative Anesthesia/Sedation Assessment       D              100.0%
# Physiotherapy Assessment All components            D              100.0%
# Physiotherapy Fall Risk Assessment                 D              100.0%
# Post Anesthesia Recovery Form                      D              100.0%
# Pre-Operative (Anaesthesia) Induction Assessment   D              100.0%
# Daily Round Notes by Physicians (ward/interdici... D               99.4%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)         D              99.24%
# Patient care orders on uniform location (Doctor... D               98.7%
# Informed Consent Form (all procedures requiring... D              98.15%
# Daily CPOE orders and Nursing signature for adm... D              97.79%
# Fall Risk Assessment, Intervention and Reassess... D              97.62%
# Physician Initial Assessment All components        D              96.97%
# Patient care orders on uniform location (Nurse'... D              96.97%
# Appropriate pain assessment, intervention and r... D              96.05%
# Nutritional Assessment All components              D              95.83%
# Nursing Initial Assessment All components          D              95.45%
# Multidisciplinary Patient and family education ... D              92.47%
# Blood Transfusion Order and monitoring Form        D               75.0%
#                                                    ND              25.0%
# Multidisciplinary Patient and family education ... ND              7.53%
# Nursing Initial Assessment All components          ND              4.55%
# Nutritional Assessment All components              ND              4.17%
# Appropriate pain assessment, intervention and r... ND              3.95%
# Patient care orders on uniform location (Nurse'... ND              3.03%
# Physician Initial Assessment All components        ND              3.03%
# Fall Risk Assessment, Intervention and Reassess... ND              2.38%
# Daily CPOE orders and Nursing signature for adm... ND              2.21%
# Informed Consent Form (all procedures requiring... ND              1.85%
# Patient care orders on uniform location (Doctor... ND               1.3%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)         ND              0.76%
# Daily Round Notes by Physicians (ward/interdici... ND               0.6%
#
#                                                            TIMELY
# DOCUMENTS                                          TIMELY
# Appropriate pain assessment, intervention and r... Y       100.0%
# Patient care orders on uniform location (Nurse'... Y       100.0%
# Daily CPOE orders and Nursing signature for adm... Y       100.0%
# Intraoperative Notes of Anesthesia                 Y       100.0%
# Intraoperative form for Site marking, sign in, ... Y       100.0%
# Nursing Initial Assessment All components          Y       100.0%
# Check the Discharge summary and DNR forms for a... Y       100.0%
# Discharge/Transfer/Referral Summary at exit        Y       100.0%
# Patient care orders on uniform location (Doctor... Y       100.0%
# Nutritional Assessment All components              Y       100.0%
# Check Consent forms for any abbreviations          Y       100.0%
# Physiotherapy Assessment All components            Y       100.0%
# Physiotherapy Fall Risk Assessment                 Y       100.0%
# Blood Transfusion Order and monitoring Form        Y       100.0%
# Pre-Operative (Anaesthesia) Induction Assessment   Y       100.0%
# Pre-Operative Anesthesia/Sedation Assessment       Y       100.0%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)         Y       99.24%
# Physician Initial Assessment All components        Y       99.22%
# Fall Risk Assessment, Intervention and Reassess... Y       98.37%
# Informed Consent Form (all procedures requiring... Y       98.11%
# Surgical Procedure/ Operative notes                Y       97.83%
# Post Anesthesia Recovery Form                      Y        88.1%
# Daily Round Notes by Physicians (ward/interdici... Y       88.02%
# Multidisciplinary Patient and family education ... Y        83.7%
#                                                    N        16.3%
# Daily Round Notes by Physicians (ward/interdici... N       11.98%
# Post Anesthesia Recovery Form                      N        11.9%
# Surgical Procedure/ Operative notes                N        2.17%
# Informed Consent Form (all procedures requiring... N        1.89%
# Fall Risk Assessment, Intervention and Reassess... N        1.63%
# Physician Initial Assessment All components        N        0.78%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)         N        0.76%
#
#                                                            LEGIBLE
# DOCUMENTS                                          LEGIBLE
# Physiotherapy Fall Risk Assessment                 Y        100.0%
# Blood Transfusion Order and monitoring Form        Y        100.0%
# Pre-Operative (Anaesthesia) Induction Assessment   Y        100.0%
# Patient care orders on uniform location (Nurse'... Y        99.22%
# Daily CPOE orders and Nursing signature for adm... Y        97.74%
# Check Consent forms for any abbreviations          Y         97.2%
# Informed Consent Form (all procedures requiring... Y        96.23%
# Appropriate pain assessment, intervention and r... Y        95.21%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)         Y        92.37%
# Multidisciplinary Patient and family education ... Y        91.11%
# Intraoperative form for Site marking, sign in, ... Y        87.23%
# Patient care orders on uniform location (Doctor... Y        86.84%
# Post Anesthesia Recovery Form                      Y        85.71%
# Fall Risk Assessment, Intervention and Reassess... Y        85.37%
# Intraoperative Notes of Anesthesia                 Y        80.95%
# Nursing Initial Assessment All components          Y        65.08%
# Physiotherapy Assessment All components            Y         65.0%
# Check the Discharge summary and DNR forms for a... Y         62.6%
# Discharge/Transfer/Referral Summary at exit        Y        61.36%
# Pre-Operative Anesthesia/Sedation Assessment       Y        60.47%
# Physician Initial Assessment All components        Y        58.59%
# Surgical Procedure/ Operative notes                Y        56.52%
# Daily Round Notes by Physicians (ward/interdici... Y        53.29%
# Nutritional Assessment All components              N        52.17%
#                                                    Y        47.83%
# Daily Round Notes by Physicians (ward/interdici... N        46.71%
# Surgical Procedure/ Operative notes                N        43.48%
# Physician Initial Assessment All components        N        41.41%
# Pre-Operative Anesthesia/Sedation Assessment       N        39.53%
# Discharge/Transfer/Referral Summary at exit        N        38.64%
# Check the Discharge summary and DNR forms for a... N         37.4%
# Physiotherapy Assessment All components            N         35.0%
# Nursing Initial Assessment All components          N        34.92%
# Intraoperative Notes of Anesthesia                 N        19.05%
# Fall Risk Assessment, Intervention and Reassess... N        14.63%
# Post Anesthesia Recovery Form                      N        14.29%
# Patient care orders on uniform location (Doctor... N        13.16%
# Intraoperative form for Site marking, sign in, ... N        12.77%
# Multidisciplinary Patient and family education ... N         8.89%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)         N         7.63%
# Appropriate pain assessment, intervention and r... N         4.79%
# Informed Consent Form (all procedures requiring... N         3.77%
# Check Consent forms for any abbreviations          N          2.8%
# Daily CPOE orders and Nursing signature for adm... N         2.26%
# Patient care orders on uniform location (Nurse'... N         0.78%
#
#                                                             COMPLETE
# DOCUMENTS                                          COMPLETE
# Nutritional Assessment All components              Y          100.0%
# Pre-Operative (Anaesthesia) Induction Assessment   Y          100.0%
# Check the Discharge summary and DNR forms for a... Y          100.0%
# Physiotherapy Fall Risk Assessment                 Y          100.0%
# Intraoperative Notes of Anesthesia                 Y          100.0%
# Intraoperative form for Site marking, sign in, ... Y          100.0%
# Check Consent forms for any abbreviations          Y          99.07%
# Discharge/Transfer/Referral Summary at exit        Y          95.45%
# Multidisciplinary Patient and family education ... Y          94.81%
# Fall Risk Assessment, Intervention and Reassess... Y           93.5%
# Post Anesthesia Recovery Form                      Y          92.86%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)         Y          90.84%
# Physiotherapy Assessment All components            Y           90.0%
# Pre-Operative Anesthesia/Sedation Assessment       Y          88.37%
# Nursing Initial Assessment All components          Y           88.1%
# Informed Consent Form (all procedures requiring... Y          87.74%
# Daily CPOE orders and Nursing signature for adm... Y          80.45%
# Surgical Procedure/ Operative notes                Y          78.26%
# Patient care orders on uniform location (Doctor... Y          77.63%
# Daily Round Notes by Physicians (ward/interdici... Y          74.85%
# Physician Initial Assessment All components        Y          74.22%
# Appropriate pain assessment, intervention and r... Y          69.86%
# Blood Transfusion Order and monitoring Form        Y          66.67%
# Patient care orders on uniform location (Nurse'... Y          58.59%
#                                                    N          41.41%
# Blood Transfusion Order and monitoring Form        N          33.33%
# Appropriate pain assessment, intervention and r... N          30.14%
# Physician Initial Assessment All components        N          25.78%
# Daily Round Notes by Physicians (ward/interdici... N          25.15%
# Patient care orders on uniform location (Doctor... N          22.37%
# Surgical Procedure/ Operative notes                N          21.74%
# Daily CPOE orders and Nursing signature for adm... N          19.55%
# Informed Consent Form (all procedures requiring... N          12.26%
# Nursing Initial Assessment All components          N           11.9%
# Pre-Operative Anesthesia/Sedation Assessment       N          11.63%
# Physiotherapy Assessment All components            N           10.0%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)         N           9.16%
# Post Anesthesia Recovery Form                      N           7.14%
# Fall Risk Assessment, Intervention and Reassess... N            6.5%
# Multidisciplinary Patient and family education ... N           5.19%
# Discharge/Transfer/Referral Summary at exit        N           4.55%
# Check Consent forms for any abbreviations          N           0.93%
#
#                                                            MET
# DOCUMENTS                                          MET
# Pre-Operative (Anaesthesia) Induction Assessment   M    100.0%
# Physiotherapy Fall Risk Assessment                 M    100.0%
# Check Consent forms for any abbreviations          M    96.26%
# Intraoperative form for Site marking, sign in, ... M    87.23%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)         M    82.58%
# Informed Consent Form (all procedures requiring... M    81.48%
# Intraoperative Notes of Anesthesia                 M    80.95%
# Daily CPOE orders and Nursing signature for adm... M    76.47%
# Fall Risk Assessment, Intervention and Reassess... M    76.19%
# Post Anesthesia Recovery Form                      M    69.05%
# Multidisciplinary Patient and family education ... M    67.12%
# Patient care orders on uniform location (Doctor... M    65.58%
# Appropriate pain assessment, intervention and r... M    64.47%
# Daily Round Notes by Physicians (ward/interdici... NM   63.69%
# Check the Discharge summary and DNR forms for a... M     62.6%
# Physiotherapy Assessment All components            M     60.0%
# Physician Initial Assessment All components        NM   59.09%
# Discharge/Transfer/Referral Summary at exit        M    57.58%
# Patient care orders on uniform location (Nurse'... M    56.06%
# Nursing Initial Assessment All components          M    54.55%
# Surgical Procedure/ Operative notes                NM   54.35%
# Nutritional Assessment All components              NM   54.17%
# Pre-Operative Anesthesia/Sedation Assessment       M    53.49%
# Blood Transfusion Order and monitoring Form        M     50.0%
#                                                    NM    50.0%
# Pre-Operative Anesthesia/Sedation Assessment       NM   46.51%
# Nutritional Assessment All components              M    45.83%
# Surgical Procedure/ Operative notes                M    45.65%
# Nursing Initial Assessment All components          NM   45.45%
# Patient care orders on uniform location (Nurse'... NM   43.94%
# Discharge/Transfer/Referral Summary at exit        NM   42.42%
# Physician Initial Assessment All components        M    40.91%
# Physiotherapy Assessment All components            NM    40.0%
# Check the Discharge summary and DNR forms for a... NM    37.4%
# Daily Round Notes by Physicians (ward/interdici... M    36.31%
# Appropriate pain assessment, intervention and r... NM   35.53%
# Patient care orders on uniform location (Doctor... NM   34.42%
# Multidisciplinary Patient and family education ... NM   32.88%
# Post Anesthesia Recovery Form                      NM   30.95%
# Fall Risk Assessment, Intervention and Reassess... NM   23.81%
# Daily CPOE orders and Nursing signature for adm... NM   23.53%
# Intraoperative Notes of Anesthesia                 NM   19.05%
# Informed Consent Form (all procedures requiring... NM   18.52%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)         NM   17.42%
# Intraoperative form for Site marking, sign in, ... NM   12.77%
# Check Consent forms for any abbreviations          NM    3.74%
# END OF OVERALL INSTITUTIONAL SCORES
# *********************************************************
#
# PHYSICIAN ONLY SCORES - DOCUMENTED
# D     99.2%
# ND     0.8%
# Name: DOCUMENTED, dtype: object
#
# PHYSICIAN ONLY SCORES - TIMELY
# Y    98.0%
# N     2.0%
# Name: TIMELY, dtype: object
#
# PHYSICIAN ONLY SCORES - LEGIBILITY
# Y    72.8%
# N    27.2%
# Name: LEGIBLE, dtype: object
#
# PHYSICIAN ONLY SCORES - COMPLETENESS
# Y    87.9%
# N    12.1%
# Name: COMPLETE, dtype: object
#
# PHYSICIAN ONLY SCORES - OVERALL SCORES
# M     63.2%
# NM    36.8%
# Name: MET, dtype: object
#
# DOCUMENTS                                                                                             DOCUMENTED
# Surgical Procedure/ Operative notes                                                                   D             100.0%
# Pre-Operative Anesthesia/Sedation Assessment                                                          D             100.0%
# Check the Discharge summary and DNR forms for any abbreviations                                       D             100.0%
# Discharge/Transfer/Referral Summary at exit                                                           D             100.0%
# Intraoperative Notes of Anesthesia                                                                    D             100.0%
# Intraoperative form for Site marking, sign in, time out and sign out                                  D             100.0%
# Check Consent forms for any abbreviations                                                             D             100.0%
# Physiotherapy Assessment All components                                                               D             100.0%
# Physiotherapy Fall Risk Assessment                                                                    D             100.0%
# Pre-Operative (Anaesthesia) Induction Assessment                                                      D             100.0%
# Daily Round Notes by Physicians (ward/interdiciplinary ICU round)                                     D              99.4%
# Patient care orders on uniform location (Doctor's part)                                               D              98.7%
# Informed Consent Form (all procedures requiring consent i.e. anesthesia, sedation, BT, chemo, dialys  D              98.1%
# Physician Initial Assessment All components                                                           D              97.0%
# Nutritional Assessment All components                                                                 D              95.8%
#                                                                                                       ND              4.2%
# Physician Initial Assessment All components                                                           ND              3.0%
# Informed Consent Form (all procedures requiring consent i.e. anesthesia, sedation, BT, chemo, dialys  ND              1.9%
# Patient care orders on uniform location (Doctor's part)                                               ND              1.3%
# Daily Round Notes by Physicians (ward/interdiciplinary ICU round)                                     ND              0.6%
# Name: DOCUMENTED, dtype: object
#
# DOCUMENTS                                                                                             TIMELY
# Nutritional Assessment All components                                                                 Y         100.0%
# Patient care orders on uniform location (Doctor's part)                                               Y         100.0%
# Check the Discharge summary and DNR forms for any abbreviations                                       Y         100.0%
# Discharge/Transfer/Referral Summary at exit                                                           Y         100.0%
# Intraoperative Notes of Anesthesia                                                                    Y         100.0%
# Intraoperative form for Site marking, sign in, time out and sign out                                  Y         100.0%
# Check Consent forms for any abbreviations                                                             Y         100.0%
# Physiotherapy Assessment All components                                                               Y         100.0%
# Physiotherapy Fall Risk Assessment                                                                    Y         100.0%
# Pre-Operative (Anaesthesia) Induction Assessment                                                      Y         100.0%
# Pre-Operative Anesthesia/Sedation Assessment                                                          Y         100.0%
# Physician Initial Assessment All components                                                           Y          99.2%
# Informed Consent Form (all procedures requiring consent i.e. anesthesia, sedation, BT, chemo, dialys  Y          98.1%
# Surgical Procedure/ Operative notes                                                                   Y          97.8%
# Daily Round Notes by Physicians (ward/interdiciplinary ICU round)                                     Y          88.0%
#                                                                                                       N          12.0%
# Surgical Procedure/ Operative notes                                                                   N           2.2%
# Informed Consent Form (all procedures requiring consent i.e. anesthesia, sedation, BT, chemo, dialys  N           1.9%
# Physician Initial Assessment All components                                                           N           0.8%
# Name: TIMELY, dtype: object
#
# DOCUMENTS                                                                                             LEGIBLE
# Pre-Operative (Anaesthesia) Induction Assessment                                                      Y          100.0%
# Physiotherapy Fall Risk Assessment                                                                    Y          100.0%
# Check Consent forms for any abbreviations                                                             Y           97.2%
# Informed Consent Form (all procedures requiring consent i.e. anesthesia, sedation, BT, chemo, dialys  Y           96.2%
# Intraoperative form for Site marking, sign in, time out and sign out                                  Y           87.2%
# Patient care orders on uniform location (Doctor's part)                                               Y           86.8%
# Intraoperative Notes of Anesthesia                                                                    Y           81.0%
# Physiotherapy Assessment All components                                                               Y           65.0%
# Check the Discharge summary and DNR forms for any abbreviations                                       Y           62.6%
# Discharge/Transfer/Referral Summary at exit                                                           Y           61.4%
# Pre-Operative Anesthesia/Sedation Assessment                                                          Y           60.5%
# Physician Initial Assessment All components                                                           Y           58.6%
# Surgical Procedure/ Operative notes                                                                   Y           56.5%
# Daily Round Notes by Physicians (ward/interdiciplinary ICU round)                                     Y           53.3%
# Nutritional Assessment All components                                                                 N           52.2%
#                                                                                                       Y           47.8%
# Daily Round Notes by Physicians (ward/interdiciplinary ICU round)                                     N           46.7%
# Surgical Procedure/ Operative notes                                                                   N           43.5%
# Physician Initial Assessment All components                                                           N           41.4%
# Pre-Operative Anesthesia/Sedation Assessment                                                          N           39.5%
# Discharge/Transfer/Referral Summary at exit                                                           N           38.6%
# Check the Discharge summary and DNR forms for any abbreviations                                       N           37.4%
# Physiotherapy Assessment All components                                                               N           35.0%
# Intraoperative Notes of Anesthesia                                                                    N           19.0%
# Patient care orders on uniform location (Doctor's part)                                               N           13.2%
# Intraoperative form for Site marking, sign in, time out and sign out                                  N           12.8%
# Informed Consent Form (all procedures requiring consent i.e. anesthesia, sedation, BT, chemo, dialys  N            3.8%
# Check Consent forms for any abbreviations                                                             N            2.8%
# Name: LEGIBLE, dtype: object
#
# DOCUMENTS                                                                                             COMPLETE
# Nutritional Assessment All components                                                                 Y           100.0%
# Intraoperative form for Site marking, sign in, time out and sign out                                  Y           100.0%
# Check the Discharge summary and DNR forms for any abbreviations                                       Y           100.0%
# Intraoperative Notes of Anesthesia                                                                    Y           100.0%
# Pre-Operative (Anaesthesia) Induction Assessment                                                      Y           100.0%
# Physiotherapy Fall Risk Assessment                                                                    Y           100.0%
# Check Consent forms for any abbreviations                                                             Y            99.1%
# Discharge/Transfer/Referral Summary at exit                                                           Y            95.5%
# Physiotherapy Assessment All components                                                               Y            90.0%
# Pre-Operative Anesthesia/Sedation Assessment                                                          Y            88.4%
# Informed Consent Form (all procedures requiring consent i.e. anesthesia, sedation, BT, chemo, dialys  Y            87.7%
# Surgical Procedure/ Operative notes                                                                   Y            78.3%
# Patient care orders on uniform location (Doctor's part)                                               Y            77.6%
# Daily Round Notes by Physicians (ward/interdiciplinary ICU round)                                     Y            74.9%
# Physician Initial Assessment All components                                                           Y            74.2%
#                                                                                                       N            25.8%
# Daily Round Notes by Physicians (ward/interdiciplinary ICU round)                                     N            25.1%
# Patient care orders on uniform location (Doctor's part)                                               N            22.4%
# Surgical Procedure/ Operative notes                                                                   N            21.7%
# Informed Consent Form (all procedures requiring consent i.e. anesthesia, sedation, BT, chemo, dialys  N            12.3%
# Pre-Operative Anesthesia/Sedation Assessment                                                          N            11.6%
# Physiotherapy Assessment All components                                                               N            10.0%
# Discharge/Transfer/Referral Summary at exit                                                           N             4.5%
# Check Consent forms for any abbreviations                                                             N             0.9%
# Name: COMPLETE, dtype: object
#
# DOCUMENTS                                                                                             MET
# Pre-Operative (Anaesthesia) Induction Assessment                                                      M      100.0%
# Physiotherapy Fall Risk Assessment                                                                    M      100.0%
# Check Consent forms for any abbreviations                                                             M       96.3%
# Intraoperative form for Site marking, sign in, time out and sign out                                  M       87.2%
# Informed Consent Form (all procedures requiring consent i.e. anesthesia, sedation, BT, chemo, dialys  M       81.5%
# Intraoperative Notes of Anesthesia                                                                    M       81.0%
# Patient care orders on uniform location (Doctor's part)                                               M       65.6%
# Daily Round Notes by Physicians (ward/interdiciplinary ICU round)                                     NM      63.7%
# Check the Discharge summary and DNR forms for any abbreviations                                       M       62.6%
# Physiotherapy Assessment All components                                                               M       60.0%
# Physician Initial Assessment All components                                                           NM      59.1%
# Discharge/Transfer/Referral Summary at exit                                                           M       57.6%
# Surgical Procedure/ Operative notes                                                                   NM      54.3%
# Nutritional Assessment All components                                                                 NM      54.2%
# Pre-Operative Anesthesia/Sedation Assessment                                                          M       53.5%
#                                                                                                       NM      46.5%
# Nutritional Assessment All components                                                                 M       45.8%
# Surgical Procedure/ Operative notes                                                                   M       45.7%
# Discharge/Transfer/Referral Summary at exit                                                           NM      42.4%
# Physician Initial Assessment All components                                                           M       40.9%
# Physiotherapy Assessment All components                                                               NM      40.0%
# Check the Discharge summary and DNR forms for any abbreviations                                       NM      37.4%
# Daily Round Notes by Physicians (ward/interdiciplinary ICU round)                                     M       36.3%
# Patient care orders on uniform location (Doctor's part)                                               NM      34.4%
# Intraoperative Notes of Anesthesia                                                                    NM      19.0%
# Informed Consent Form (all procedures requiring consent i.e. anesthesia, sedation, BT, chemo, dialys  NM      18.5%
# Intraoperative form for Site marking, sign in, time out and sign out                                  NM      12.8%
# Check Consent forms for any abbreviations                                                             NM       3.7%
# Name: MET, dtype: object
# END OF PHYSICIAN SCORES
# *********************************************************
#
# NURSES ONLY SCORES - DOCUMENTED
# D     96.5%
# ND     3.5%
# Name: DOCUMENTED, dtype: object
#
# NURSES ONLY SCORES - TIMELY
# Y    96.9%
# N     3.1%
# Name: TIMELY, dtype: object
#
# NURSES ONLY SCORES - LEGIBILITY
# Y    89.6%
# N    10.4%
# Name: LEGIBLE, dtype: object
#
# NURSES ONLY SCORES - COMPLETENESS
# Y    82.5%
# N    17.5%
# Name: COMPLETE, dtype: object
#
# NURSES ONLY SCORES - OVERALL SCORES
# M     68.1%
# NM    31.9%
# Name: MET, dtype: object
#
# DOCUMENTS                                                                      DOCUMENTED
# Post Anesthesia Recovery Form                                                  D             100.0%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)                                     D              99.2%
# Daily CPOE orders and Nursing signature for administration                     D              97.8%
# Fall Risk Assessment, Intervention and Reassessment                            D              97.6%
# Patient care orders on uniform location (Nurse's part)                         D              97.0%
# Appropriate pain assessment, intervention and reassessment                     D              96.1%
# Nursing Initial Assessment All components                                      D              95.5%
# Multidisciplinary Patient and family education Form from arrival to discharge  D              92.5%
# Blood Transfusion Order and monitoring Form                                    D              75.0%
#                                                                                ND             25.0%
# Multidisciplinary Patient and family education Form from arrival to discharge  ND              7.5%
# Nursing Initial Assessment All components                                      ND              4.5%
# Appropriate pain assessment, intervention and reassessment                     ND              3.9%
# Patient care orders on uniform location (Nurse's part)                         ND              3.0%
# Fall Risk Assessment, Intervention and Reassessment                            ND              2.4%
# Daily CPOE orders and Nursing signature for administration                     ND              2.2%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)                                     ND              0.8%
# Name: DOCUMENTED, dtype: object
#
# DOCUMENTS                                                                      TIMELY
# Patient care orders on uniform location (Nurse's part)                         Y         100.0%
# Nursing Initial Assessment All components                                      Y         100.0%
# Daily CPOE orders and Nursing signature for administration                     Y         100.0%
# Blood Transfusion Order and monitoring Form                                    Y         100.0%
# Appropriate pain assessment, intervention and reassessment                     Y         100.0%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)                                     Y          99.2%
# Fall Risk Assessment, Intervention and Reassessment                            Y          98.4%
# Post Anesthesia Recovery Form                                                  Y          88.1%
# Multidisciplinary Patient and family education Form from arrival to discharge  Y          83.7%
#                                                                                N          16.3%
# Post Anesthesia Recovery Form                                                  N          11.9%
# Fall Risk Assessment, Intervention and Reassessment                            N           1.6%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)                                     N           0.8%
# Name: TIMELY, dtype: object
#
# DOCUMENTS                                                                      LEGIBLE
# Blood Transfusion Order and monitoring Form                                    Y          100.0%
# Patient care orders on uniform location (Nurse's part)                         Y           99.2%
# Daily CPOE orders and Nursing signature for administration                     Y           97.7%
# Appropriate pain assessment, intervention and reassessment                     Y           95.2%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)                                     Y           92.4%
# Multidisciplinary Patient and family education Form from arrival to discharge  Y           91.1%
# Post Anesthesia Recovery Form                                                  Y           85.7%
# Fall Risk Assessment, Intervention and Reassessment                            Y           85.4%
# Nursing Initial Assessment All components                                      Y           65.1%
#                                                                                N           34.9%
# Fall Risk Assessment, Intervention and Reassessment                            N           14.6%
# Post Anesthesia Recovery Form                                                  N           14.3%
# Multidisciplinary Patient and family education Form from arrival to discharge  N            8.9%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)                                     N            7.6%
# Appropriate pain assessment, intervention and reassessment                     N            4.8%
# Daily CPOE orders and Nursing signature for administration                     N            2.3%
# Patient care orders on uniform location (Nurse's part)                         N            0.8%
# Name: LEGIBLE, dtype: object
#
# DOCUMENTS                                                                      COMPLETE
# Multidisciplinary Patient and family education Form from arrival to discharge  Y           94.8%
# Fall Risk Assessment, Intervention and Reassessment                            Y           93.5%
# Post Anesthesia Recovery Form                                                  Y           92.9%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)                                     Y           90.8%
# Nursing Initial Assessment All components                                      Y           88.1%
# Daily CPOE orders and Nursing signature for administration                     Y           80.5%
# Appropriate pain assessment, intervention and reassessment                     Y           69.9%
# Blood Transfusion Order and monitoring Form                                    Y           66.7%
# Patient care orders on uniform location (Nurse's part)                         Y           58.6%
#                                                                                N           41.4%
# Blood Transfusion Order and monitoring Form                                    N           33.3%
# Appropriate pain assessment, intervention and reassessment                     N           30.1%
# Daily CPOE orders and Nursing signature for administration                     N           19.5%
# Nursing Initial Assessment All components                                      N           11.9%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)                                     N            9.2%
# Post Anesthesia Recovery Form                                                  N            7.1%
# Fall Risk Assessment, Intervention and Reassessment                            N            6.5%
# Multidisciplinary Patient and family education Form from arrival to discharge  N            5.2%
# Name: COMPLETE, dtype: object
#
# DOCUMENTS                                                                      MET
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)                                     M      82.6%
# Daily CPOE orders and Nursing signature for administration                     M      76.5%
# Fall Risk Assessment, Intervention and Reassessment                            M      76.2%
# Post Anesthesia Recovery Form                                                  M      69.0%
# Multidisciplinary Patient and family education Form from arrival to discharge  M      67.1%
# Appropriate pain assessment, intervention and reassessment                     M      64.5%
# Patient care orders on uniform location (Nurse's part)                         M      56.1%
# Nursing Initial Assessment All components                                      M      54.5%
# Blood Transfusion Order and monitoring Form                                    NM     50.0%
#                                                                                M      50.0%
# Nursing Initial Assessment All components                                      NM     45.5%
# Patient care orders on uniform location (Nurse's part)                         NM     43.9%
# Appropriate pain assessment, intervention and reassessment                     NM     35.5%
# Multidisciplinary Patient and family education Form from arrival to discharge  NM     32.9%
# Post Anesthesia Recovery Form                                                  NM     31.0%
# Fall Risk Assessment, Intervention and Reassessment                            NM     23.8%
# Daily CPOE orders and Nursing signature for administration                     NM     23.5%
# Nursing Re-Assessment (MEWS, PEWS & MEOWS)                                     NM     17.4%
# Name: MET, dtype: object
# END OF NURSING SCORES
# *********************************************************
